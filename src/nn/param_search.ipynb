# %% [markdown]
# ## Hyperparameter search
# The cells below are for checking the results of the experiments run in param_search.py.

# %%
import pandas as pd

df = pd.read_csv('output/parameters_search1.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0  round_epochs        loss   val_acc       acc    val_loss  \
# 0           30           100    3.857924  0.850299  0.999334    4.695037
# 1          174           100    5.197034  0.844311  0.999334    6.032562
# 2           45           100    5.045124  0.842315  0.999334    5.894371
# 3           96           100    4.596838  0.830339  0.998003    5.012912
# 4          148           100   24.845076  0.810379  0.988016   24.915226
# 5          173           100    5.680221  0.804391  0.995340    6.600401
# 6           35           100    4.231609  0.800399  0.992676    4.976052
# 7           93           100   28.942360  0.752495  0.889481   28.671249
# 8          120           100   25.841370  0.750499  0.986684   25.869919
# 9           98           100   40.803169  0.702595  0.900133   40.349247
# 10          59           100   77.349899  0.674651  0.990013   76.235847
# 11         169           100   12.776766  0.660679  0.991345   13.417793
# ...

# %%
df2 = pd.read_csv('output/parameters_search2.csv')
df2.head(20)

# %%
np.sort(np.unique(df["lr"].values))

# %%
# Train.

train_loss, train_acc = model.evaluate(X_train, y_train)

print('Train loss:', train_loss)
print('Train accuracy:', train_acc)
