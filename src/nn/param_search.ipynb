# %% [markdown]
# ## Hyperparameter Search Results
#
# This notebook checks the results of the experiments run in `param_search.py` and `param_search2.py`.

# %%
import pandas as pd

df = pd.read_csv('output/model1_test3.csv')
df.head(20)
# Out:
#     Unnamed: 0  round_epochs   val_loss   val_acc       loss       acc  \
# 0          101           100   2.442799  0.892216   1.748921  0.999334
# 1          177           100   2.370863  0.880240   1.618858  1.000000
# 2           25           100  13.870365  0.864271  13.138552  1.000000
# 3           83           100   3.202496  0.854291   2.307986  0.998668
# 4          167           100   4.671400  0.854291   3.917216  0.972037
# 5          170           100   4.117745  0.846307   3.569735  0.985353
# 6           56           100   6.046474  0.842315   5.142360  1.000000
# 7           62           100   4.370182  0.842315   3.575948  0.996005
# 8          161           100   2.766847  0.836327   1.973746  0.996671
# 9            7           100   7.027945  0.836327   6.513790  0.970706
# 10         119           100   6.927390  0.834331   6.404155  0.980692
# 11          73           100   3.181145  0.830339   2.313938  0.999334
# ...
