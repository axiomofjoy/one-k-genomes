# %% [markdown]
# ## Hyperparameter search
# The cells below are for checking the results of the experiments run in param_search.py.

# %%
import numpy as np

10 ** np.linspace(-4, 4 , 9)
# Out:
# array([1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03,
#        1.e+04])

# %%
import pandas as pd

df = pd.read_csv('output/model2_test1.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0  round_epochs       val_loss   val_acc           loss  \
# 0            4           100       6.340549  0.101796       3.264593
# 1           91           100       5.873276  0.081836       2.722338
# 2          142           100     536.990234  0.075848     536.957031
# 3           82           100      36.630196  0.075848      34.133396
# 4           19           100       5.552340  0.075848       2.445236
# 5           88           100      33.706467  0.075848       4.091419
# 6            5           100      57.837254  0.073852      39.996483
# 7           42           100      38.525192  0.071856      35.235611
# 8          133           100      19.828079  0.069860      19.558239
# 9          114           100      15.800282  0.069860      13.028440
# 10          13           100  529783.687500  0.069860  529783.687500
# 11         103           100    3254.317871  0.067864      39.891930
# 12          37           100      20.321272  0.067864       7.355419
# 13          61           100      22.084503  0.067864       7.383997
# 14          97           100      27.409641  0.067864      25.982836
# 15         102           100      12.618736  0.065868       9.740105
# 16          33           100  104919.718750  0.065868  107556.937500
# 17          30           100       7.665922  0.065868       4.698028
# 18          51           100      21.949408  0.065868       7.327250
# 19          54           100      15.435298  0.065868      12.614667
#
#          acc  dropout_input  dropout_hidden         reg       lr  epochs
# 0   0.996671            0.2             0.2      0.0100    0.010     100
# 1   1.000000            0.2             0.0      0.0100    0.010     100
# 2   0.144474            0.1             0.0     10.0000    1.000     100
# 3   0.709720            0.1             0.4      0.0100    0.100     100
# 4   1.000000            0.1             0.2      0.0100    0.010     100
# 5   0.872170            0.0             0.2      0.0001    1.000     100
# 6   0.160453            0.2             0.0      0.0100   10.000     100
# 7   0.812916            0.0             0.2      0.1000    0.100     100
# 8   0.348202            0.2             0.0      1.0000    0.100     100
# 9   0.934754            0.2             0.4      0.1000    0.010     100
# 10  0.062583            0.0             0.4  10000.0000    1.000     100
# 11  0.146471            0.0             0.0      0.0100  100.000     100
# 12  0.900799            0.1             0.4      0.0010    0.100     100
# 13  0.884820            0.2             0.4      0.0010    0.100     100
# 14  0.520639            0.0             0.0      1.0000    0.100     100
# 15  0.965379            0.0             0.4      0.1000    0.010     100
# 16  0.397470            0.2             0.0  10000.0000    0.001     100
# 17  0.984021            0.2             0.4      0.0100    0.010     100
# 18  0.285619            0.1             0.4      0.0010    1.000     100
# 19  0.982690            0.2             0.0      1.0000    0.010     100

# %%
np.sort(np.unique(df["lr"].values))

# %%
# Train.

train_loss, train_acc = model.evaluate(X_train, y_train)

print('Train loss:', train_loss)
print('Train accuracy:', train_acc)
